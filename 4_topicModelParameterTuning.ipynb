# %%
#!jupyter nbconvert --to script 'topicModelParameterTuning.ipynb'

# %%
from collections import defaultdict
from pyspark.ml.linalg import Vectors, SparseVector
from pyspark.ml.clustering import LDA
from pyspark.sql import SQLContext
import re
from nltk.corpus import stopwords
from pyspark import SparkContext

sc = SparkContext.getOrCreate()
# check if spark context is defined
print(sc.version)
import time
# Out:
# 2.3.2

# %%
data = sc.wholeTextFiles("file:///data2/sunandan/sparkex/sshrotri/allAbstracts/*.txt").map(lambda x: x[1])

# %%
# Tokenize the data
tokens = data.map(lambda document: document.strip().lower()) \
    .map(lambda x: x.split()) \
    .map(lambda word: [x for x in word if x.isalpha()]) \
    .map(lambda word: [x for x in word if len(x) > 2])

# %%
tokens.take(5)
# Out:
# [['cytochrome',
#   'enzyme',
#   'metabolizes',
#   'the',
#   'anticancer',
#   'prodrug',
#   'cyclophosphamide',
#   'which',
#   'decomposes',
#   'the',
#   'cytotoxic',
#   'metabolites',
#   'acrolein',
#   'and',
#   'phosphoramide',
#   'have',
#   'evaluated',
#   'the',
#   'bystander',
#   'cytotoxicity',
#   'cpa',
#   'combination',
#   'with',
#   'enzyme',
#   'prodrug',
#   'therapy',
#   'using',
#   'cell',
#   'agarose',
#   'overlay',
#   'this',
#   'method',
#   'mimics',
#   'the',
#   'tumor',
#   'microenvironment',
#   'limiting',
#   'the',
#   'diffusion',
#   'metabolites',
#   'and',
#   'reducing',
#   'the',
#   'oxygen',
#   'concentration',
#   'levels',
#   'similar',
#   'those',
#   'found',
#   'solid',
#   'under',
#   'these',
#   'the',
#   'cyp',
#   'activity',
#   'tumor',
#   'cells',
#   'was',
#   'decreased',
#   'compared',
#   'standard',
#   'aerobic',
#   'despite',
#   'this',
#   'decrease',
#   'metabolic',
#   'potent',
#   'bystander',
#   'effect',
#   'was',
#   'resulting',
#   'killing',
#   'cpa',
#   'tumor',
#   'cell',
#   'population',
#   'comprised',
#   'only',
#   'tumor',
#   'transient',
#   'transfection',
#   'small',
#   'fraction',
#   'human',
#   'hepatoma',
#   'cell',
#   'population',
#   'with',
#   'expression',
#   'plasmid',
#   'followed',
#   'treatment',
#   'with',
#   'cpa',
#   'led',
#   'eradication',
#   'the',
#   'such',
#   'bystander',
#   'effect',
#   'was',
#   'observed',
#   'without',
#   'the',
#   'agarose',
#   'these',
#   'findings',
#   'suggest',
#   'that',
#   'the',
#   'agarose',
#   'overlay',
#   'technique',
#   'very',
#   'useful',
#   'vitro',
#   'test',
#   'system',
#   'for',
#   'investigation',
#   'the',
#   'bystander',
#   'effect',
#   'and',
#   'other',
#   'combinations',
#   'under',
#   'conditions',
#   'that',
#   'mimic',
#   'the',
#   'hypoxic',
#   'conditions',
#   'present',
#   'solid',
#   'tumors'],
#  ['this',
#   'review',
#   'summarizes',
#   'clinical',
#   'experience',
#   'with',
#   'infectious',
#   'disease',
#   'vaccines',
#   'and',
#   'data',
#   'from',
#   'animal',
#   'tumor',
#   'models',
#   'that',
#   'support',
#   'paradigm',
#   'shift',
#   'for',
#   'cancer',
#   'vaccines',
#   'from',
#   'therapeutic',
#   'prevention'],
#  ['because',
#   'their',
#   'ability',
#   'the',
#   'relationships',
#   'oncolytic',
#   'viruses',
#   'cannot',
#   'easily',
#   'better',
#   'understand',
#   'the',
#   'pharmacokinetics',
#   'virotherapy',
#   'relation',
#   'viral',
#   'dose',
#   'and',
#   'administered',
#   'intraperitoneally',
#   'orthotopic',
#   'mouse',
#   'model',
#   'ovarian',
#   'attenuated',
#   'oncolytic',
#   'measles',
#   'virus',
#   'engineered',
#   'express',
#   'soluble',
#   'human',
#   'carcinoembryonic',
#   'antigen',
#   'and',
#   'the',
#   'virus',
#   'currently',
#   'undergoing',
#   'phase',
#   'clinical',
#   'testing',
#   'patients',
#   'with',
#   'ovarian',
#   'plasma',
#   'cea',
#   'levels',
#   'correlate',
#   'with',
#   'numbers',
#   'tumor',
#   'cells',
#   'given',
#   'and',
#   'were',
#   'used',
#   'surrogate',
#   'monitor',
#   'the',
#   'profiles',
#   'viral',
#   'gene',
#   'expression',
#   'over',
#   'the',
#   'antineoplastic',
#   'activity',
#   'was',
#   'apparent',
#   'over',
#   'wide',
#   'range',
#   'virus',
#   'doses',
#   'with',
#   'little',
#   'reduction',
#   'observed',
#   'antitumor',
#   'even',
#   'the',
#   'lowest',
#   'tested',
#   'analysis',
#   'cea',
#   'profiles',
#   'treated',
#   'mice',
#   'was',
#   'highly',
#   'illustrating',
#   'the',
#   'variability',
#   'virus',
#   'kinetics',
#   'different',
#   'dose',
#   'the',
#   'highest',
#   'doses',
#   'virus',
#   'were',
#   'associated',
#   'with',
#   'higher',
#   'initial',
#   'levels',
#   'tumor',
#   'cell',
#   'but',
#   'the',
#   'final',
#   'outcome',
#   'therapy',
#   'all',
#   'dose',
#   'levels',
#   'was',
#   'partial',
#   'equilibrium',
#   'between',
#   'virus',
#   'and',
#   'resulting',
#   'significant',
#   'slowing',
#   'tumor',
#   'growth',
#   'and',
#   'enhanced',
#   'survival',
#   'the'],
#  ['mortality',
#   'due',
#   'colorectal',
#   'cancer',
#   'high',
#   'and',
#   'associated',
#   'with',
#   'the',
#   'development',
#   'liver',
#   'approximately',
#   'human',
#   'crcs',
#   'harbor',
#   'activating',
#   'mutation',
#   'the',
#   'kras',
#   'tumor',
#   'cells',
#   'with',
#   'activated',
#   'kras',
#   'are',
#   'particularly',
#   'sensitive',
#   'reovirus',
#   'oncolytic',
#   'the',
#   'efficacy',
#   'therapies',
#   'may',
#   'positively',
#   'negatively',
#   'modulated',
#   'the',
#   'host',
#   'immune',
#   'this',
#   'study',
#   'was',
#   'designed',
#   'assess',
#   'the',
#   'effect',
#   'immunosuppression',
#   'reovirus',
#   'oncolysis',
#   'established',
#   'colorectal',
#   'micrometastases',
#   'the',
#   'mouse',
#   'crc',
#   'cells',
#   'harbor',
#   'mutant',
#   'kras',
#   'gene',
#   'and',
#   'are',
#   'susceptible',
#   'oncolysis',
#   'reovirus',
#   'isolated',
#   'liver',
#   'tumors',
#   'were',
#   'established',
#   'syngenic',
#   'immunocompetent',
#   'mice',
#   'intrahepatic',
#   'reovirus',
#   'therapy',
#   'was',
#   'given',
#   'single',
#   'intratumoral',
#   'injection',
#   'control',
#   'mice',
#   'and',
#   'cyclosporin',
#   'immunosuppressed',
#   'tumor',
#   'growth',
#   'was',
#   'analyzed',
#   'over',
#   'time',
#   'bioluminescence',
#   'the',
#   'outgrowth',
#   'established',
#   'crc',
#   'liver',
#   'metastases',
#   'immunocompetent',
#   'mice',
#   'was',
#   'efficiently',
#   'but',
#   'temporarily',
#   'inhibited',
#   'with',
#   'single',
#   'injection',
#   'reovirus',
#   'immunosuppression',
#   'with',
#   'cyclosporin',
#   'markedly',
#   'increased',
#   'and',
#   'prolonged',
#   'the',
#   'therapeutic',
#   'effect',
#   'and',
#   'allowed',
#   'complete',
#   'reovirus',
#   'tumor',
#   'eradication',
#   'subpopulation',
#   'the',
#   'conclude',
#   'that',
#   'reovirus',
#   'effective',
#   'therapeutic',
#   'agent',
#   'against',
#   'established',
#   'colorectal',
#   'liver',
#   'metastases',
#   'and',
#   'that',
#   'immunosuppression',
#   'enhances',
#   'treatment'],
#  ['previous',
#   'studies',
#   'have',
#   'shown',
#   'that',
#   'the',
#   'human',
#   'melanoma',
#   'has',
#   'activity',
#   'vitro',
#   'and',
#   'vitro',
#   'studies',
#   'using',
#   'human',
#   'peripheral',
#   'blood',
#   'mononuclear',
#   'cells',
#   'indicate',
#   'that',
#   'has',
#   'the',
#   'individual',
#   'properties',
#   'have',
#   'been',
#   'previously',
#   'examined',
#   'there',
#   'not',
#   'single',
#   'study',
#   'that',
#   'has',
#   'examined',
#   'antitumor',
#   'and',
#   'proimmune',
#   'properties',
#   'the',
#   'tumor',
#   'suppressive',
#   'activity',
#   'and',
#   'the',
#   'cytokine',
#   'activity',
#   'have',
#   'not',
#   'been',
#   'previously',
#   'tested',
#   'immunocompetent',
#   'therefore',
#   'the',
#   'present',
#   'study',
#   'evaluated',
#   'the',
#   'antitumor',
#   'and',
#   'immune',
#   'properties',
#   'murine',
#   'syngeneic',
#   'tumor',
#   'gene',
#   'transfer',
#   'murine',
#   'fibrosarcoma',
#   'and',
#   'normal',
#   'cells',
#   'significantly',
#   'inhibited',
#   'growth',
#   'and',
#   'induced',
#   'apoptosis',
#   'tumor',
#   'cells',
#   'but',
#   'not',
#   'normal',
#   'intratumoral',
#   'administration',
#   'resulted',
#   'significant',
#   'inhibition',
#   'tumor',
#   'growth',
#   'with',
#   'subset',
#   'mice',
#   'showing',
#   'complete',
#   'tumor',
#   'next',
#   'evaluated',
#   'the',
#   'immune',
#   'potentiation',
#   'activity',
#   'cancer',
#   'vaccine',
#   'cells',
#   'transfected',
#   'with',
#   'and',
#   'injected',
#   'into',
#   'syngeneic',
#   'immunocompetent',
#   'mice',
#   'were',
#   'unable',
#   'they',
#   'did',
#   'grow',
#   'immunocompromised',
#   'nude',
#   'these',
#   'when',
#   'challenged',
#   'with',
#   'parental',
#   'tumor',
#   'cells',
#   'experienced',
#   'tumor',
#   'suggesting',
#   'induction',
#   'systemic',
#   'splenocytes',
#   'prepared',
#   'from',
#   'vaccinated',
#   'mice',
#   'demonstrated',
#   'higher',
#   'proliferative',
#   'activity',
#   'and',
#   'produced',
#   'elevated',
#   'levels',
#   'cytokines',
#   'compared',
#   'with',
#   'those',
#   'from',
#   'control',
#   'vitro',
#   'subset',
#   'analysis',
#   'splenocytes',
#   'from',
#   'vaccinated',
#   'mice',
#   'demonstrated',
#   'significant',
#   'increase',
#   'the',
#   'but',
#   'not',
#   'the',
#   'cell',
#   'population',
#   'thus',
#   'treatment',
#   'syngeneic',
#   'tumors',
#   'induces',
#   'tumor',
#   'cell',
#   'death',
#   'and',
#   'promotes',
#   'immune',
#   'leading',
#   'anticancer']]

# %%
stop = stopwords.words('english')
# Get vocabulary 
# Flat map to put words into one giant list
# Remove stopwords
# Map and then reduce by key
# Sort by word count
termCounts = tokens.flatMap(lambda document: document) \
    .filter(lambda x: x not in stop) \
    .map(lambda word: (word,1)) \
    .reduceByKey(lambda x,y: x+y) \
    .map(lambda tuple: (tuple[1],tuple[0])) \
    .sortByKey(False)

# %%
termCounts.take(10)
# Out:
# [(12096, 'gene'),
#  (11168, 'cells'),
#  (9428, 'expression'),
#  (9028, 'cell'),
#  (9028, 'cancer'),
#  (7785, 'tumor'),
#  (7289, 'patients'),
#  (6981, 'genetic'),
#  (5893, 'human'),
#  (5285, 'associated')]

# %%
# Dictionary
vocabulary = termCounts.map(lambda x: x[1]) \
    .zipWithIndex() \
    .collectAsMap()

# %%
vocabulary
# Out:
# {'gene': 0,
#  'cells': 1,
#  'expression': 2,
#  'cell': 3,
#  'cancer': 4,
#  'tumor': 5,
#  'patients': 6,
#  'genetic': 7,
#  'human': 8,
#  'associated': 9,
#  'clinical': 10,
#  'results': 11,
#  'genes': 12,
#  'using': 13,
#  'study': 14,
#  'may': 15,
#  'also': 16,
#  'protein': 17,
#  'two': 18,
#  'identified': 19,
#  'variants': 20,
#  'mutations': 21,
#  'analysis': 22,
#  'data': 23,
#  'found': 24,
#  'disease': 25,
#  'association': 26,
#  'increased': 27,
#  'growth': 28,
#  'showed': 29,
#  'significantly': 30,
#  'novel': 31,
#  'role': 32,
#  'dna': 33,
#  'treatment': 34,
#  'therapy': 35,
#  'studies': 36,
#  'one': 37,
#  'compared': 38,
#  'levels': 39,
#  'significant': 40,
#  'risk': 41,
#  'mice': 42,
#  'therapeutic': 43,
#  'potential': 44,
#  'used': 45,
#  'mutation': 46,
#  'including': 47,
#  'breast': 48,
#  'could': 49,
#  'high': 50,
#  'observed': 51,
#  'factor': 52,
#  'effect': 53,
#  'activity': 54,
#  'three': 55,
#  'sequencing': 56,
#  'vector': 57,
#  'show': 58,
#  'tumors': 59,
#  'effects': 60,
#  'new': 61,
#  'different': 62,
#  'suggest': 63,
#  'findings': 64,
#  'development': 65,
#  'target': 66,
#  'important': 67,
#  'molecular': 68,
#  'revealed': 69,
#  'family': 70,
#  'demonstrated': 71,
#  'common': 72,
#  'signaling': 73,
#  'reported': 74,
#  'immune': 75,
#  'type': 76,
#  'promoter': 77,
#  'variant': 78,
#  'well': 79,
#  'vectors': 80,
#  'vivo': 81,
#  'previously': 82,
#  'control': 83,
#  'virus': 84,
#  'individuals': 85,
#  'among': 86,
#  'response': 87,
#  'receptor': 88,
#  'activation': 89,
#  'evidence': 90,
#  'polymorphisms': 91,
#  'vitro': 92,
#  'model': 93,
#  'first': 94,
#  'reduced': 95,
#  'number': 96,
#  'multiple': 97,
#  'region': 98,
#  'genomic': 99,
#  'within': 100,
#  'although': 101,
#  'mouse': 102,
#  'higher': 103,
#  'functional': 104,
#  'present': 105,
#  'lung': 106,
#  'testing': 107,
#  'several': 108,
#  'delivery': 109,
#  'provide': 110,
#  'known': 111,
#  'patient': 112,
#  'cases': 113,
#  'complex': 114,
#  'specific': 115,
#  'allele': 116,
#  'survival': 117,
#  'inhibition': 118,
#  'performed': 119,
#  'normal': 120,
#  'primary': 121,
#  'syndrome': 122,
#  'induced': 123,
#  'susceptibility': 124,
#  'expressed': 125,
#  'identify': 126,
#  'function': 127,
#  'major': 128,
#  'screening': 129,
#  'report': 130,
#  'demonstrate': 131,
#  'involved': 132,
#  'approach': 133,
#  'population': 134,
#  'increase': 135,
#  'use': 136,
#  'highly': 137,
#  'viral': 138,
#  'single': 139,
#  'whether': 140,
#  'transcription': 141,
#  'enhanced': 142,
#  'loss': 143,
#  'shown': 144,
#  'based': 145,
#  'kinase': 146,
#  'pathway': 147,
#  'four': 148,
#  'factors': 149,
#  'whereas': 150,
#  'decreased': 151,
#  'transfer': 152,
#  'investigated': 153,
#  'effective': 154,
#  'mechanisms': 155,
#  'combination': 156,
#  'lines': 157,
#  'detected': 158,
#  'apoptosis': 159,
#  'many': 160,
#  'cellular': 161,
#  'rare': 162,
#  'large': 163,
#  'research': 164,
#  'affected': 165,
#  'targeting': 166,
#  'rna': 167,
#  'phenotype': 168,
#  'chromosome': 169,
#  'via': 170,
#  'system': 171,
#  'mechanism': 172,
#  'snps': 173,
#  'resulted': 174,
#  'either': 175,
#  'low': 176,
#  'developed': 177,
#  'resistance': 178,
#  'test': 179,
#  'prostate': 180,
#  'level': 181,
#  'caused': 182,
#  'without': 183,
#  'group': 184,
#  'early': 185,
#  'transduction': 186,
#  'cause': 187,
#  'overexpression': 188,
#  'families': 189,
#  'targeted': 190,
#  'proliferation': 191,
#  'information': 192,
#  'suggesting': 193,
#  'characterized': 194,
#  'polymorphism': 195,
#  'severe': 196,
#  'antitumor': 197,
#  'small': 198,
#  'total': 199,
#  'efficacy': 200,
#  'frequency': 201,
#  'linkage': 202,
#  'stem': 203,
#  'deletion': 204,
#  'presence': 205,
#  'due': 206,
#  'mrna': 207,
#  'expressing': 208,
#  'binding': 209,
#  'confirmed': 210,
#  'combined': 211,
#  'tissue': 212,
#  'diagnosis': 213,
#  'blood': 214,
#  'strategy': 215,
#  'following': 216,
#  'controls': 217,
#  'sequence': 218,
#  'candidate': 219,
#  'liver': 220,
#  'med': 221,
#  'similar': 222,
#  'genet': 223,
#  'recent': 224,
#  'proteins': 225,
#  'likely': 226,
#  'pathogenic': 227,
#  'indicate': 228,
#  'various': 229,
#  'encoding': 230,
#  'key': 231,
#  'samples': 232,
#  'loci': 233,
#  'lower': 234,
#  'analyzed': 235,
#  'injection': 236,
#  'infection': 237,
#  'transcriptional': 238,
#  'metastasis': 239,
#  'critical': 240,
#  'current': 241,
#  'alleles': 242,
#  'additional': 243,
#  'mutant': 244,
#  'health': 245,
#  'metastatic': 246,
#  'regulation': 247,
#  'genome': 248,
#  'responses': 249,
#  'inhibited': 250,
#  'treated': 251,
#  'haplotype': 252,
#  'analyses': 253,
#  'progression': 254,
#  'adenovirus': 255,
#  'evaluated': 256,
#  'examined': 257,
#  'carcinoma': 258,
#  'populations': 259,
#  'ability': 260,
#  'systemic': 261,
#  'ovarian': 262,
#  'time': 263,
#  'regions': 264,
#  'transgene': 265,
#  'related': 266,
#  'might': 267,
#  'efficient': 268,
#  'murine': 269,
#  'oncolytic': 270,
#  'diagnostic': 271,
#  'disorder': 272,
#  'recombinant': 273,
#  'genotype': 274,
#  'direct': 275,
#  'age': 276,
#  'mitochondrial': 277,
#  'tested': 278,
#  'regulatory': 279,
#  'resulting': 280,
#  'correlated': 281,
#  'understanding': 282,
#  'autosomal': 283,
#  'strong': 284,
#  'five': 285,
#  'administration': 286,
#  'nuclear': 287,
#  'cohort': 288,
#  'knockdown': 289,
#  'medical': 290,
#  'models': 291,
#  'variation': 292,
#  'determine': 293,
#  'positive': 294,
#  'production': 295,
#  'independent': 296,
#  'leading': 297,
#  'support': 298,
#  'result': 299,
#  'disorders': 300,
#  'induction': 301,
#  'remains': 302,
#  'formation': 303,
#  'established': 304,
#  'death': 305,
#  'bone': 306,
#  'methylation': 307,
#  'would': 308,
#  'features': 309,
#  'genetics': 310,
#  'required': 311,
#  'underlying': 312,
#  'diseases': 313,
#  'thus': 314,
#  'possible': 315,
#  'healthy': 316,
#  'previous': 317,
#  'locus': 318,
#  'recessive': 319,
#  'epithelial': 320,
#  'melanoma': 321,
#  'changes': 322,
#  'associations': 323,
#  'pathways': 324,
#  'pancreatic': 325,
#  'heterozygous': 326,
#  'homozygous': 327,
#  'rate': 328,
#  'interaction': 329,
#  'method': 330,
#  'promising': 331,
#  'investigate': 332,
#  'induce': 333,
#  'brain': 334,
#  'years': 335,
#  'improved': 336,
#  'form': 337,
#  'invasion': 338,
#  'replication': 339,
#  'provides': 340,
#  'drug': 341,
#  'subjects': 342,
#  'snp': 343,
#  'ratio': 344,
#  'containing': 345,
#  'differences': 346,
#  'reduction': 347,
#  'clinically': 348,
#  'poor': 349,
#  'improve': 350,
#  'malignant': 351,
#  'japanese': 352,
#  'inflammatory': 353,
#  'children': 354,
#  'exon': 355,
#  'markers': 356,
#  'missense': 357,
#  'adenoviral': 358,
#  'oncogenic': 359,
#  'muscle': 360,
#  'tissues': 361,
#  'inhibitor': 362,
#  'led': 363,
#  'migration': 364,
#  'contribute': 365,
#  'six': 366,
#  'serum': 367,
#  'individual': 368,
#  'impact': 369,
#  'plasmid': 370,
#  'efficiency': 371,
#  'limited': 372,
#  'across': 373,
#  'strategies': 374,
#  'less': 375,
#  'suggested': 376,
#  'least': 377,
#  'transduced': 378,
#  'sensitivity': 379,
#  'nucleotide': 380,
#  'often': 381,
#  'colorectal': 382,
#  'carrying': 383,
#  'activated': 384,
#  'inherited': 385,
#  'included': 386,
#  'determined': 387,
#  'available': 388,
#  'indicated': 389,
#  'types': 390,
#  'despite': 391,
#  'suggests': 392,
#  'phosphorylation': 393,
#  'review': 394,
#  'influence': 395,
#  'recently': 396,
#  'participants': 397,
#  'genetically': 398,
#  'negative': 399,
#  'identification': 400,
#  'consistent': 401,
#  'essential': 402,
#  'antigen': 403,
#  'domain': 404,
#  'directly': 405,
#  'site': 406,
#  'colon': 407,
#  'carriers': 408,
#  'distinct': 409,
#  'quantitative': 410,
#  'describe': 411,
#  'carrier': 412,
#  'endothelial': 413,
#  'located': 414,
#  'assessed': 415,
#  'relevant': 416,
#  'groups': 417,
#  'transfection': 418,
#  'targets': 419,
#  'conducted': 420,
#  'evaluate': 421,
#  'considered': 422,
#  'even': 423,
#  'described': 424,
#  'generated': 425,
#  'spectrum': 426,
#  'tumour': 427,
#  'acid': 428,
#  'european': 429,
#  'approaches': 430,
#  'elevated': 431,
#  'central': 432,
#  'short': 433,
#  'enzyme': 434,
#  'autoimmune': 435,
#  'phenotypes': 436,
#  'develop': 437,
#  'obtained': 438,
#  'familial': 439,
#  'biological': 440,
#  'exome': 441,
#  'studied': 442,
#  'tests': 443,
#  'functions': 444,
#  'dominant': 445,
#  'promotes': 446,
#  'derived': 447,
#  'metabolic': 448,
#  'deficiency': 449,
#  'useful': 450,
#  'haplotypes': 451,
#  'upon': 452,
#  'implicated': 453,
#  'need': 454,
#  'roles': 455,
#  'class': 456,
#  'future': 457,
#  'potentially': 458,
#  'followed': 459,
#  'taken': 460,
#  'copy': 461,
#  'cancers': 462,
#  'basis': 463,
#  'responsible': 464,
#  'increasing': 465,
#  'history': 466,
#  'process': 467,
#  'strongly': 468,
#  'diabetes': 469,
#  'women': 470,
#  'aim': 471,
#  'cytokine': 472,
#  'suppressor': 473,
#  'methods': 474,
#  'linked': 475,
#  'upregulated': 476,
#  'overall': 477,
#  'phenotypic': 478,
#  'indicating': 479,
#  'chronic': 480,
#  'congenital': 481,
#  'greater': 482,
#  'sites': 483,
#  'promote': 484,
#  'injected': 485,
#  'silencing': 486,
#  'glioma': 487,
#  'novo': 488,
#  'mediated': 489,
#  'line': 490,
#  'frequently': 491,
#  'inhibitors': 492,
#  'set': 493,
#  'lead': 494,
#  'unrelated': 495,
#  'active': 496,
#  'xenograft': 497,
#  'correlation': 498,
#  'days': 499,
#  'coding': 500,
#  'prevalence': 501,
#  'peripheral': 502,
#  'affect': 503,
#  'genotyped': 504,
#  'potent': 505,
#  'assess': 506,
#  'antibody': 507,
#  'downstream': 508,
#  'enhance': 509,
#  'cardiac': 510,
#  'alternative': 511,
#  'able': 512,
#  'cytotoxic': 513,
#  'vascular': 514,
#  'assay': 515,
#  'cycle': 516,
#  'regulated': 517,
#  'still': 518,
#  'frequencies': 519,
#  'detection': 520,
#  'decrease': 521,
#  'better': 522,
#  'express': 523,
#  'gastric': 524,
#  'deletions': 525,
#  'suppressed': 526,
#  'hcc': 527,
#  'unique': 528,
#  'conditions': 529,
#  'selected': 530,
#  'increases': 531,
#  'transfected': 532,
#  'majority': 533,
#  'complete': 534,
#  'marker': 535,
#  'crc': 536,
#  'per': 537,
#  'regulator': 538,
#  'developmental': 539,
#  'regression': 540,
#  'leads': 541,
#  'members': 542,
#  'chromosomal': 543,
#  'confidence': 544,
#  'provided': 545,
#  'suppression': 546,
#  'genotypes': 547,
#  'reporter': 548,
#  'receptors': 549,
#  'case': 550,
#  'aav': 551,
#  'upregulation': 552,
#  'isolated': 553,
#  'range': 554,
#  'importance': 555,
#  'pathogenesis': 556,
#  'specifically': 557,
#  'regarding': 558,
#  'host': 559,
#  'therapies': 560,
#  'sample': 561,
#  'remain': 562,
#  'addition': 563,
#  'local': 564,
#  'maternal': 565,
#  'knowledge': 566,
#  'intellectual': 567,
#  'vaccine': 568,
#  'lentiviral': 569,
#  'exhibited': 570,
#  'significance': 571,
#  'applied': 572,
#  'lack': 573,
#  'causes': 574,
#  'especially': 575,
#  'distribution': 576,
#  'variations': 577,
#  'signal': 578,
#  'particularly': 579,
#  'infected': 580,
#  'produced': 581,
#  'repair': 582,
#  'aimed': 583,
#  'differentiation': 584,
#  'chain': 585,
#  'absence': 586,
#  'hearing': 587,
#  'inhibit': 588,
#  'second': 589,
#  'downregulation': 590,
#  'nude': 591,
#  'surface': 592,
#  'prenatal': 593,
#  'predicted': 594,
#  'animal': 595,
#  'animals': 596,
#  'invasive': 597,
#  'intratumoral': 598,
#  'adult': 599,
#  'male': 600,
#  'depletion': 601,
#  'involving': 602,
#  'relative': 603,
#  'size': 604,
#  'eight': 605,
#  'seven': 606,
#  'general': 607,
#  'subsequent': 608,
#  'rates': 609,
#  'developing': 610,
#  'currently': 611,
#  'regulates': 612,
#  'splicing': 613,
#  'onset': 614,
#  'therefore': 615,
#  'chinese': 616,
#  'damage': 617,
#  'sequences': 618,
#  'part': 619,
#  'sle': 620,
#  'induces': 621,
#  'interactions': 622,
#  'selection': 623,
#  'plasma': 624,
#  'yet': 625,
#  'accumulation': 626,
#  'efficiently': 627,
#  'seen': 628,
#  'molecules': 629,
#  'application': 630,
#  'fusion': 631,
#  'sirna': 632,
#  'assays': 633,
#  'newborn': 634,
#  'presented': 635,
#  'panel': 636,
#  'represent': 637,
#  'array': 638,
#  'experimental': 639,
#  'defects': 640,
#  'include': 641,
#  'dose': 642,
#  'extracellular': 643,
#  'tool': 644,
#  'heart': 645,
#  'repeat': 646,
#  'herpes': 647,
#  'status': 648,
#  'estimated': 649,
#  'resistant': 650,
#  'rat': 651,
#  'long': 652,
#  'modified': 653,
#  'leukemia': 654,
#  'renal': 655,
#  'effectively': 656,
#  'egfr': 657,
#  'natural': 658,
#  'advanced': 659,
#  'interval': 660,
#  'given': 661,
#  'represents': 662,
#  'affecting': 663,
#  'crucial': 664,
#  'hereditary': 665,
#  'variety': 666,
#  'simplex': 667,
#  'genotyping': 668,
#  'received': 669,
#  'work': 670,
#  'parental': 671,
#  'skin': 672,
#  'endogenous': 673,
#  'frequent': 674,
#  'epigenetic': 675,
#  'diagnosed': 676,
#  'thereby': 677,
#  'utility': 678,
#  'capacity': 679,
#  'largely': 680,
#  'parents': 681,
#  'conventional': 682,
#  'alone': 683,
#  'achieved': 684,
#  'transition': 685,
#  'specificity': 686,
#  'female': 687,
#  'regulating': 688,
#  'fibroblasts': 689,
#  'regulate': 690,
#  'odds': 691,
#  'acute': 692,
#  'hla': 693,
#  'care': 694,
#  'alterations': 695,
#  'recurrent': 696,
#  'luciferase': 697,
#  'help': 698,
#  'viruses': 699,
#  'order': 700,
#  'promoted': 701,
#  'measured': 702,
#  'toward': 703,
#  'protective': 704,
#  'stable': 705,
#  'relatively': 706,
#  'membrane': 707,
#  'chromatin': 708,
#  'carried': 709,
#  'phase': 710,
#  'conclude': 711,
#  'generation': 712,
#  'matrix': 713,
#  'main': 714,
#  'western': 715,
#  'value': 716,
#  'much': 717,
#  'constructed': 718,
#  'heterogeneity': 719,
#  'disequilibrium': 720,
#  'detect': 721,
#  'difference': 722,
#  'variable': 723,
#  'evaluation': 724,
#  'explore': 725,
#  'selective': 726,
#  'secondary': 727,
#  'dependent': 728,
#  'implications': 729,
#  'propose': 730,
#  'cnvs': 731,
#  'designed': 732,
#  'impaired': 733,
#  'cytotoxicity': 734,
#  'necrosis': 735,
#  'shows': 736,
#  'characteristics': 737,
#  'aggressive': 738,
#  'inhibits': 739,
#  'weeks': 740,
#  'plays': 741,
#  'little': 742,
#  'play': 743,
#  'aberrant': 744,
#  'public': 745,
#  'african': 746,
#  'experiments': 747,
#  'intracellular': 748,
#  'together': 749,
#  'providing': 750,
#  'fluorescent': 751,
#  'reveal': 752,
#  'severity': 753,
#  'fetal': 754,
#  'solid': 755,
#  'subset': 756,
#  'component': 757,
#  'overexpressed': 758,
#  'heterogeneous': 759,
#  'prognosis': 760,
#  'safety': 761,
#  'abnormal': 762,
#  'outcomes': 763,
#  'comprehensive': 764,
#  'germline': 765,
#  'skeletal': 766,
#  'approximately': 767,
#  'antibodies': 768,
#  'expansion': 769,
#  'encodes': 770,
#  'mammary': 771,
#  'engineered': 772,
#  'microarray': 773,
#  'stress': 774,
#  'initial': 775,
#  'comparison': 776,
#  'causative': 777,
#  'defined': 778,
#  'poorly': 779,
#  'immunity': 780,
#  'sufficient': 781,
#  'somatic': 782,
#  'emt': 783,
#  'mass': 784,
#  'causal': 785,
#  'delivered': 786,
#  'abnormalities': 787,
#  'score': 788,
#  'histone': 789,
#  'anticancer': 790,
#  'ligand': 791,
#  'angiogenesis': 792,
#  'altered': 793,
#  'contributes': 794,
#  'outcome': 795,
#  'pattern': 796,
#  'reduce': 797,
#  'retinal': 798,
#  'structure': 799,
#  'proportion': 800,
#  'involvement': 801,
#  'quality': 802,
#  'pten': 803,
#  'highest': 804,
#  'inhibiting': 805,
#  'elements': 806,
#  'administered': 807,
#  'peptide': 808,
#  'since': 809,
#  'contribution': 810,
#  'diverse': 811,
#  'tumorigenesis': 812,
#  'laboratory': 813,
#  'shared': 814,
#  'structural': 815,
#  'preclinical': 816,
#  'radiation': 817,
#  'pcr': 818,
#  'progressive': 819,
#  'proposed': 820,
#  'context': 821,
#  'tyrosine': 822,
#  'subcutaneous': 823,
#  'agents': 824,
#  'identifying': 825,
#  'guidelines': 826,
#  'facilitate': 827,
#  'adhesion': 828,
#  'relationship': 829,
#  'rapid': 830,
#  'commonly': 831,
#  'hematopoietic': 832,
#  'standard': 833,
#  'find': 834,
#  'mainly': 835,
#  'downregulated': 836,
#  'assessment': 837,
#  'akt': 838,
#  'markedly': 839,
#  'examine': 840,
#  'chemotherapy': 841,
#  'culture': 842,
#  'published': 843,
#  'mutated': 844,
#  'patterns': 845,
#  'asthma': 846,
#  'imaging': 847,
#  'transgenic': 848,
#  'criteria': 849,
#  'trials': 850,
#  'prolonged': 851,
#  'properties': 852,
#  'made': 853,
#  'mild': 854,
#  'successful': 855,
#  'secretion': 856,
#  'body': 857,
#  'reverse': 858,
#  'point': 859,
#  'management': 860,
#  'toxicity': 861,
#  'exons': 862,
#  'change': 863,
#  'exposure': 864,
#  'metabolism': 865,
#  'activities': 866,
#  'months': 867,
#  'forms': 868,
#  'polymerase': 869,
#  'processes': 870,
#  'remained': 871,
#  'lymphocytes': 872,
#  'necessary': 873,
#  'differential': 874,
#  'allelic': 875,
#  'amino': 876,
#  'screened': 877,
#  'protection': 878,
#  'wide': 879,
#  'consent': 880,
#  'mean': 881,
#  'highlight': 882,
#  'muscular': 883,
#  'apoptotic': 884,
#  'events': 885,
#  'particular': 886,
#  'stage': 887,
#  'understand': 888,
#  'degradation': 889,
#  'fully': 890,
#  'validated': 891,
#  'capable': 892,
#  'retroviral': 893,
#  'genomics': 894,
#  'lupus': 895,
#  'hepatic': 896,
#  'design': 897,
#  'vaccination': 898,
#  'nine': 899,
#  'demonstrates': 900,
#  'green': 901,
#  'address': 902,
#  'member': 903,
#  'incidence': 904,
#  'showing': 905,
#  'global': 906,
#  'investigation': 907,
#  'mesenchymal': 908,
#  'suicide': 909,
#  'inhibitory': 910,
#  'along': 911,
#  'confirm': 912,
#  'mirnas': 913,
#  'systems': 914,
#  'promoting': 915,
#  'inducing': 916,
#  'upstream': 917,
#  'discovery': 918,
#  'finding': 919,
#  'certain': 920,
#  'symptoms': 921,
#  'splice': 922,
#  'unknown': 923,
#  'intron': 924,
#  'prevent': 925,
#  'day': 926,
#  'according': 927,
#  'counseling': 928,
#  'attenuated': 929,
#  'uptake': 930,
#  'marked': 931,
#  'versus': 932,
#  'serve': 933,
#  'components': 934,
#  'enhances': 935,
#  'powerful': 936,
#  'another': 937,
#  'causing': 938,
#  'ethnic': 939,
#  'technology': 940,
#  'become': 941,
#  'molecule': 942,
#  'activating': 943,
#  'treat': 944,
#  'interfering': 945,
#  'compound': 946,
#  'glucose': 947,
#  'sporadic': 948,
#  'pediatric': 949,
#  'rats': 950,
#  'bladder': 951,
#  'reports': 952,
#  'primarily': 953,
#  'cytokines': 954,
#  'origin': 955,
#  'mammalian': 956,
#  'sustained': 957,
#  'initiation': 958,
#  'larger': 959,
#  'generate': 960,
#  'needed': 961,
#  'transcripts': 962,
#  'displayed': 963,
#  'stability': 964,
#  'killing': 965,
#  'whole': 966,
#  'whose': 967,
#  'extensive': 968,
#  'prognostic': 969,
#  'insights': 970,
#  'transmission': 971,
#  'pulmonary': 972,
#  'males': 973,
#  'widely': 974,
#  'discuss': 975,
#  'average': 976,
#  'conserved': 977,
#  'substantial': 978,
#  'sensitive': 979,
#  'minor': 980,
#  'embryonic': 981,
#  'american': 982,
#  'cdna': 983,
#  'glioblastoma': 984,
#  'signals': 985,
#  'advances': 986,
#  'benefit': 987,
#  'clear': 988,
#  'cervical': 989,
#  'establish': 990,
#  'newly': 991,
#  'possibility': 992,
#  'occurred': 993,
#  'overcome': 994,
#  'allow': 995,
#  'best': 996,
#  'indicates': 997,
#  'numerous': 998,
#  'decision': 999,
#  ...}

# %%
# Convert a given document into a vector of word counts
def document_vector(document):
    id = document[1]
    counts = defaultdict(int)
    for token in document[0]:
        if token in vocabulary:
            token_id = vocabulary[token]
            counts[token_id] += 1
    counts = sorted(counts.items())
    keys = [x[0] for x in counts]
    values = [x[1] for x in counts]
    return (id, SparseVector(len(vocabulary), keys, values))

# Process all the documents into word vector using above function
documents = tokens.zipWithIndex().map(document_vector).map(list)

# %%
documents.take(3)
# Out:
# [[0,
#   SparseVector(29342, {1: 1.0, 2: 1.0, 3: 3.0, 5: 4.0, 8: 1.0, 13: 1.0, 24: 1.0, 34: 1.0, 35: 1.0, 38: 1.0, 39: 1.0, 51: 1.0, 53: 3.0, 54: 1.0, 59: 1.0, 63: 1.0, 64: 1.0, 92: 1.0, 105: 1.0, 134: 2.0, 151: 1.0, 156: 1.0, 171: 1.0, 179: 1.0, 183: 1.0, 198: 1.0, 222: 1.0, 256: 1.0, 280: 1.0, 330: 1.0, 363: 1.0, 370: 1.0, 391: 1.0, 418: 1.0, 434: 2.0, 448: 1.0, 450: 1.0, 459: 1.0, 505: 1.0, 513: 1.0, 521: 1.0, 529: 2.0, 734: 1.0, 755: 2.0, 790: 1.0, 833: 1.0, 907: 1.0, 965: 1.0, 1100: 1.0, 1109: 4.0, 1140: 2.0, 1180: 1.0, 1226: 1.0, 1263: 1.0, 1390: 1.0, 1439: 1.0, 1645: 1.0, 1820: 1.0, 1971: 1.0, 2341: 1.0, 2413: 1.0, 2533: 1.0, 2580: 1.0, 3121: 2.0, 3150: 1.0, 3349: 3.0, 3396: 1.0, 3804: 1.0, 4344: 1.0, 5124: 1.0, 5159: 1.0, 7235: 3.0, 12074: 1.0, 12668: 1.0, 13944: 2.0, 14360: 1.0, 27411: 1.0, 27412: 1.0})],
#  [1,
#   SparseVector(29342, {4: 1.0, 5: 1.0, 10: 1.0, 23: 1.0, 25: 1.0, 43: 1.0, 291: 1.0, 298: 1.0, 394: 1.0, 595: 1.0, 1127: 1.0, 1275: 1.0, 1326: 2.0, 1783: 1.0, 1875: 1.0, 3314: 1.0, 3805: 1.0})],
#  [2,
#   SparseVector(29342, {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 5: 3.0, 6: 1.0, 8: 1.0, 9: 1.0, 10: 1.0, 22: 1.0, 28: 1.0, 35: 1.0, 39: 3.0, 40: 1.0, 42: 1.0, 45: 1.0, 51: 1.0, 54: 1.0, 62: 1.0, 84: 6.0, 93: 1.0, 102: 1.0, 103: 1.0, 107: 1.0, 117: 1.0, 137: 1.0, 138: 2.0, 142: 1.0, 197: 1.0, 251: 1.0, 260: 1.0, 262: 2.0, 270: 2.0, 278: 1.0, 280: 1.0, 347: 1.0, 403: 1.0, 423: 1.0, 522: 1.0, 523: 1.0, 554: 1.0, 611: 1.0, 624: 1.0, 642: 3.0, 661: 1.0, 699: 1.0, 710: 1.0, 742: 1.0, 772: 1.0, 775: 1.0, 795: 1.0, 804: 1.0, 807: 1.0, 879: 1.0, 888: 1.0, 929: 1.0, 1034: 2.0, 1074: 1.0, 1105: 1.0, 1115: 1.0, 1152: 2.0, 1173: 1.0, 1379: 1.0, 1647: 1.0, 1713: 1.0, 1745: 1.0, 1765: 1.0, 1828: 1.0, 2157: 1.0, 2426: 1.0, 2601: 1.0, 2736: 1.0, 2811: 1.0, 2854: 1.0, 2905: 1.0, 3392: 2.0, 3484: 1.0, 3572: 1.0, 4243: 1.0, 4514: 1.0, 5030: 1.0, 5503: 1.0, 5864: 1.0, 6435: 1.0, 7935: 1.0})]]

# %%
df = documents.toDF(['doc_id', 'features'])

# %%
df.show()
# Out:
# +------+--------------------+
# |doc_id|            features|
# +------+--------------------+
# |     0|(29342,[1,2,3,5,8...|
# |     1|(29342,[4,5,10,23...|
# |     2|(29342,[0,1,2,3,5...|
# |     3|(29342,[0,1,4,5,8...|
# |     4|(29342,[0,1,3,4,5...|
# |     5|(29342,[5,9,11,15...|
# |     6|(29342,[0,1,2,3,4...|
# |     7|(29342,[0,1,4,5,8...|
# |     8|(29342,[1,2,4,8,1...|
# |     9|(29342,[0,1,2,3,4...|
# |    10|(29342,[0,5,6,11,...|
# |    11|(29342,[2,3,4,5,8...|
# |    12|(29342,[0,1,3,4,5...|
# |    13|(29342,[0,2,3,4,5...|
# |    14|(29342,[1,3,5,8,1...|
# |    15|(29342,[0,1,2,15,...|
# |    16|(29342,[1,4,6,8,9...|
# |    17|(29342,[0,2,15,17...|
# |    18|(29342,[0,4,15,25...|
# |    19|(29342,[0,2,5,12,...|
# +------+--------------------+
# only showing top 20 rows

# %%
# create spark dataframe
#df = spark.createDataFrame(documents, ["doc_id", "features"])
# split into training and testing data
dfs = df.randomSplit([0.85, 0.15])
dfTrain = dfs[0]
dfTest = dfs[1]

# %%
dfTrain.show()
# Out:
# +------+--------------------+
# |doc_id|            features|
# +------+--------------------+
# |     0|(29342,[1,2,3,5,8...|
# |     1|(29342,[4,5,10,23...|
# |     2|(29342,[0,1,2,3,5...|
# |     3|(29342,[0,1,4,5,8...|
# |     4|(29342,[0,1,3,4,5...|
# |     5|(29342,[5,9,11,15...|
# |     6|(29342,[0,1,2,3,4...|
# |     7|(29342,[0,1,4,5,8...|
# |     8|(29342,[1,2,4,8,1...|
# |     9|(29342,[0,1,2,3,4...|
# |    10|(29342,[0,5,6,11,...|
# |    11|(29342,[2,3,4,5,8...|
# |    13|(29342,[0,2,3,4,5...|
# |    14|(29342,[1,3,5,8,1...|
# |    15|(29342,[0,1,2,15,...|
# |    16|(29342,[1,4,6,8,9...|
# |    17|(29342,[0,2,15,17...|
# |    18|(29342,[0,4,15,25...|
# |    19|(29342,[0,2,5,12,...|
# |    20|(29342,[0,1,2,7,8...|
# +------+--------------------+
# only showing top 20 rows

# %%
dfTrain.count()
# Out:
# 11210

# %%
# choose different values of topics
Ks = [k for k in range(2, 21)]
# topic prior, determines how sparse or non-sparse the topics are 
betas = [0.05, 0.1, 2., 5.]
# initialize LDA model 
lda_model = LDA(seed=10, optimizer='online', maxIter=2000)
# number of documents
D = dfTrain.count()

output = []

for K in Ks:
    for beta in betas:
        t=time.time()
        # per document proportion prior, based on Griffiths et. al, 2004
        alpha = [50/K for _ in range(K)]
        # set parameters in model accordingly
        lda_model.setParams(k=K, docConcentration=alpha, topicConcentration=beta)
        # fit model
        df_fit = lda_model.fit(dfTrain)
        # get fit perplexity
        df_perp = df_fit.logPerplexity(dfTest)
        
        print('Perplexity={} for K={}, alpha={}, beta={}'.format(df_perp, K, 50/K, beta))
        output.append(['Perplexity={} for K={}, alpha={}, beta={}'.format(df_perp, K, 50/K, beta)])
        print(time.time()-t)
# Out:
# Perplexity=8.855095541683063 for K=2, alpha=25.0, beta=0.05
# 1285.8037214279175
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-82ae51885e5f> in <module>
#      20         lda_model.setParams(k=K, docConcentration=alpha, topicConcentration=beta)
#      21         # fit model
# ---> 22         df_fit = lda_model.fit(dfTrain)
#      23         # get fit perplexity
#      24         df_perp = df_fit.logPerplexity(dfTest)
#
# /usr/local/spark/python/pyspark/ml/base.py in fit(self, dataset, params)
#     130                 return self.copy(params)._fit(dataset)
#     131             else:
# --> 132                 return self._fit(dataset)
#     133         else:
#     134             raise ValueError("Params must be either a param map or a list/tuple of param maps, "
#
# /usr/local/spark/python/pyspark/ml/wrapper.py in _fit(self, dataset)
#     286
#     287     def _fit(self, dataset):
# --> 288         java_model = self._fit_java(dataset)
#     289         model = self._create_model(java_model)
#     290         return self._copyValues(model)
#
# /usr/local/spark/python/pyspark/ml/wrapper.py in _fit_java(self, dataset)
#     283         """
#     284         self._transfer_params_to_java()
# --> 285         return self._java_obj.fit(dataset._jdf)
#     286
#     287     def _fit(self, dataset):
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# /usr/local/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
with open('modelTuningResults', 'w') as f:
    for item in output:
        f.write("%s\n" % item)
